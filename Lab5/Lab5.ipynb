# %%
import numpy as np

import re
from collections import Counter
from typing import Any, List, Tuple, Dict
import time

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

# %%
DEVICE = "mps" if torch.backends.mps.is_available() else "cuda" if torch.cuda.is_available() else "cpu"
n_epochs = 50

# %%
def simple_tokenize(text: str) -> List[str]:
    text = text.lower()
    text = re.sub(r"([.,!?;:()\"'])", r" \1 ", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text.split()


def load_poems() -> str:
    with open("poems.txt", "r", encoding="utf-8") as f:
        return f.read()


def build_vocab(tokens: List[str], min_freq: int = 1) -> Tuple[Dict[str, int], Dict[int, str]]:
    counts = Counter(tokens)
    vocab = ["<pad>", "<unk>", "<bos>", "<eos>"]
    for w, c in counts.items():
        if c >= min_freq and w not in vocab:
            vocab.append(w)
    stoi = {w: i for i, w in enumerate(vocab)}
    itos = {i: w for w, i in stoi.items()}
    return stoi, itos


def tokens_to_ids(tokens: List[str], stoi: Dict[str, int]) -> List[int]:
    unk = stoi["<unk>"]
    return [stoi.get(t, unk) for t in tokens]


def make_sequences(ids: List[int], seq_len: int) -> Tuple[List[List[int]], List[List[int]]]:
    X, Y = [], []
    for i in range(0, len(ids) - seq_len):
        x = ids[i:i+seq_len]
        y = ids[i+1:i+seq_len+1]
        X.append(x)
        Y.append(y)
    return X, Y


def text_quality_metrics(text: str) -> Dict[str, Any]:
    toks = simple_tokenize(text)
    if not toks:
        return {
            "token_count": 0,
            "unique_tokens": 0,
            "unique_ratio": 0.0,
            "repeat_2gram_ratio": 0.0,
            "repeat_3gram_ratio": 0.0,
            "top_tokens": [],
        }

    counts = Counter(toks)
    token_count = len(toks)
    unique_tokens = len(counts)
    unique_ratio = unique_tokens / max(token_count, 1)

    def repeat_ngram_ratio(n: int) -> float:
        if len(toks) < n:
            return 0.0
        ngrams = list(zip(*[toks[i:] for i in range(n)]))
        c = Counter(ngrams)
        repeats = sum(v - 1 for v in c.values() if v > 1)
        return repeats / max(len(ngrams), 1)

    return {
        "token_count": int(token_count),
        "unique_tokens": int(unique_tokens),
        "unique_ratio": float(unique_ratio),
        "repeat_2gram_ratio": float(repeat_ngram_ratio(2)),
        "repeat_3gram_ratio": float(repeat_ngram_ratio(3)),
        "top_tokens": [(w, int(c)) for w, c in counts.most_common(10)],
    }

# %%
def softmax(x):
    x = x - np.max(x)
    e = np.exp(x)
    return e / np.sum(e)


def one_hot(idx, V):
    v = np.zeros((V, 1))
    v[idx] = 1.0
    return v


class ScratchRNN:
    def __init__(self, vocab_size, hidden_size=64, lr=1e-2, seed=42):
        rng = np.random.default_rng(seed)
        self.V = vocab_size
        self.H = hidden_size
        self.lr = lr

        self.Wxh = rng.normal(0, 0.01, (self.H, self.V))
        self.Whh = rng.normal(0, 0.01, (self.H, self.H))
        self.Why = rng.normal(0, 0.01, (self.V, self.H))
        self.bh = np.zeros((self.H, 1))
        self.by = np.zeros((self.V, 1))

    def forward(self, inputs, hprev):
        xs, hs, ys, ps = {}, {}, {}, {}
        hs[-1] = hprev

        for t, idx in enumerate(inputs):
            xs[t] = one_hot(idx, self.V)
            hs[t] = np.tanh(self.Wxh @ xs[t] + self.Whh @ hs[t-1] + self.bh)
            ys[t] = self.Why @ hs[t] + self.by
            ps[t] = softmax(ys[t].ravel()).reshape(-1, 1)
        return xs, hs, ps

    def loss_and_grads(self, inputs, targets, hprev):
        xs, hs, ps = self.forward(inputs, hprev)

        loss = 0.0
        for t in range(len(inputs)):
            loss += -np.log(ps[t][targets[t], 0] + 1e-12)

        dWxh = np.zeros_like(self.Wxh)
        dWhh = np.zeros_like(self.Whh)
        dWhy = np.zeros_like(self.Why)
        dbh = np.zeros_like(self.bh)
        dby = np.zeros_like(self.by)

        dhnext = np.zeros((self.H, 1))

        for t in reversed(range(len(inputs))):
            dy = ps[t].copy()

            dy[targets[t]] -= 1.0
            dWhy += dy @ hs[t].T
            dby += dy

            dh = self.Why.T @ dy + dhnext
            dhraw = (1 - hs[t] * hs[t]) * dh
            dbh += dhraw
            dWxh += dhraw @ xs[t].T
            dWhh += dhraw @ hs[t-1].T
            dhnext = self.Whh.T @ dhraw

        for d in [dWxh, dWhh, dWhy, dbh, dby]:
            np.clip(d, -5, 5, out=d)

        hlast = hs[len(inputs)-1]
        return loss, (dWxh, dWhh, dWhy, dbh, dby), hlast

    def step(self, grads):
        dWxh, dWhh, dWhy, dbh, dby = grads
        self.Wxh -= self.lr * dWxh
        self.Whh -= self.lr * dWhh
        self.Why -= self.lr * dWhy
        self.bh -= self.lr * dbh
        self.by -= self.lr * dby

    def sample(self, start_idx, itos, length=30, temperature=1.0):
        h = np.zeros((self.H, 1))
        x = one_hot(start_idx, self.V)
        out = []

        for _ in range(length):
            h = np.tanh(self.Wxh @ x + self.Whh @ h + self.bh)
            y = self.Why @ h + self.by
            p = softmax((y.ravel() / max(temperature, 1e-6)))
            idx = np.random.choice(range(self.V), p=p)
            out.append(itos[idx])
            x = one_hot(idx, self.V)
        return " ".join(out)


def rnn_main_short_run():
    text = load_poems()
    tokens = ["<bos>"] + simple_tokenize(text) + ["<eos>"]
    stoi, itos = build_vocab(tokens, min_freq=1)
    ids = tokens_to_ids(tokens, stoi)

    rnn = ScratchRNN(vocab_size=len(stoi), hidden_size=128, lr=0.05)
    seq_len = 25
    h = np.zeros((rnn.H, 1))

    epoch_times = []
    samples = []

    for epoch in range(n_epochs):
        t0 = time.perf_counter()
        total_loss = 0.0
        n = 0
        for i in range(0, len(ids) - seq_len - 1, seq_len):
            inp = ids[i:i+seq_len]
            tgt = ids[i+1:i+seq_len+1]
            loss, grads, h = rnn.loss_and_grads(inp, tgt, h)
            rnn.step(grads)
            total_loss += loss
            n += 1

        avg = total_loss / max(n, 1)

        sample = rnn.sample(stoi["<bos>"], itos, length=30, temperature=0.9)
        samples.append(sample)

        t1 = time.perf_counter()
        epoch_times.append(float(t1 - t0))

        print(f"Epoch {epoch+1} | avg loss: {avg:.4f}")
        print("Sample:", sample)
        print(f"Epoch time: {epoch_times[-1]:.3f}s")

    return epoch_times, samples[-1]

scratch_rnn_epoch_times, scratch_rnn_last_sample = rnn_main_short_run()
# Out:
# Epoch 1 | avg loss: 301.3461
# Sample: back to in our my in our for in when this in emma this in place this seen when this wild emma ' , our this in emma this in
# Epoch time: 71.842s
# Epoch 2 | avg loss: 323.4304
# Sample: darken’d : our emma are wild our emma are wild , emma are wild our emma are wild our emma are wild skiff emma are wild our emma are wild
# Epoch time: 74.364s
# Epoch 3 | avg loss: 367.3105
# Sample: fetching gave and wild ; green and wild ; green ' wild our emma this wild our emma this wild it emma this wild our green this wild our emma
# Epoch time: 77.057s
# Epoch 4 | avg loss: 365.7155
# Sample: crowd see of , and name are , seen name our , seen name are , seen told our , and told of , and myself to , and name
# Epoch time: 73.863s
# Epoch 5 | avg loss: 366.0527
# Sample: hang said had thee it have had we they have had years our emma thoughtful we they have had we they inward had name are have had we it have
# Epoch time: 75.023s
# Epoch 6 | avg loss: 364.6420
# Sample: crucifix er they , seen wild speak , seen wild they , seen wild they , seen wild speak green seen wild they , seen wild they , may wild
# Epoch time: 71.084s
# Epoch 7 | avg loss: 362.9818
# Sample: circuit cannot ' wild to , this wild to , this wild our , this wild to , this wild to , this wild to of this wild to of
# Epoch time: 69.715s
# Epoch 8 | avg loss: 361.2134
# Sample: dolorum see it have this yet they have this lover it have this ! they have this call it have this name to have this name look have this street
# Epoch time: 69.645s
# Epoch 9 | avg loss: 359.9116
# Sample: breast old ' call to flows and wild to spot ' name to reign ' attribute to spot and name to emma and bares our emma and wild to blossomless
# Epoch time: 70.367s
# Epoch 10 | avg loss: 358.7984
# Sample: mocking-bird repay that green and wild our green and to our green and wild our green and wild our green air distant our green mild wild our of and wild
# Epoch time: 70.096s
# Epoch 11 | avg loss: 357.4299
# Sample: sea-gaps jaws seen call our of seen name our of and name our of seen flight our of and contribute other , seen call our of seen name our of
# Epoch time: 69.783s
# Epoch 12 | avg loss: 356.1512
# Sample: wintry hue to of the wild to by the wild to of the wild to emma seen wild to punctually the wild to of cause wild to of and wild
# Epoch time: 69.968s
# Epoch 13 | avg loss: 358.6934
# Sample: sharp-hoof together doubt produce our emma the name our emma the name our embraced the name our much the market our emma the blossoms our so the name our emma
# Epoch time: 69.666s
# Epoch 14 | avg loss: 357.6939
# Sample: ahoy sound off emma softened name to emma seen songs to emma seen real to emma seen thrall to boughs seen thirteen to pale and drift to beyond seen name
# Epoch time: 69.494s
# Epoch 15 | avg loss: 357.2044
# Sample: mass trifling dictionary making it short , debris it short the call of short , we it short , utterly it short the least it short , ‘and it short
# Epoch time: 69.466s
# Epoch 16 | avg loss: 355.5087
# Sample: boughs hat our three seen , to nor seen brood to three and mountain-cottage to emma and in to years and , our years seen in to three fiery leaves
# Epoch time: 71.697s
# Epoch 17 | avg loss: 353.6780
# Sample: depress till and whom bad have and beauty they have and s idle have and away speak have and mountain-cottage flake have and distant they have and snow-flakes below have
# Epoch time: 69.376s
# Epoch 18 | avg loss: 355.3171
# Epoch time: 76.699s
# Epoch 37 | avg loss: 353.0148
# Sample: cannot fitness ' name our , and years our , and years our , , years our three and name our of and years our , , years our of
# Epoch time: 82.152s
# Epoch 38 | avg loss: 354.8569
# Sample: help soon it , i whom of , space name why , breathe thee of , become name to , i name our , the name to , the steamships
# Epoch time: 76.119s
# Epoch 39 | avg loss: 352.9689
# Sample: victors fat seen and they have seen name our have seen name they have emerging name our have may name our have and least our have seen ) leaves have
# Epoch time: 72.100s
# Epoch 40 | avg loss: 354.1297
# Sample: women gaudy of makes and dear our emma and name they years and —at our emma and name of lamb and name our emma and prevailed our emma and name
# Epoch time: 71.688s
# Epoch 41 | avg loss: 355.6671
# Sample: junction fix seen call , , and heels speak , and told speak emma and sallies they , and brook speak , and removed , , and produce they ,
# Epoch time: 70.538s
# Epoch 42 | avg loss: 353.3901
# Sample: regular dear it green seen did to green and did to green seen yew to green seen did to green seen did to green and told to green and thee
# Epoch time: 70.500s
# Epoch 43 | avg loss: 352.6963
# Sample: judaea most this wild our have this wild of emma this wild our emma this wild our emma this wild our have this wild our have this wild idle slowly
# Epoch time: 70.518s
# Epoch 44 | avg loss: 354.8499
# Sample: it—it hang , , and produce , , seen rising , , and on , , the call , , may call , , and heart , emma and name
# Epoch time: 71.859s
# Epoch 45 | avg loss: 354.4059
# Sample: understand moving seen yet ; , the steps ; , and did ; , seen call ; , and mysterious ; , the told ; , and being ; ,
# Epoch time: 71.265s
# Epoch 46 | avg loss: 355.2251
# Sample: ago see extoller trace the wild moves emma the name , emma the years they emma the years speak emma the and they emma the name our emma the sleep—the
# Epoch time: 71.227s
# Epoch 47 | avg loss: 353.0827
# Sample: carry lose this least our emma this firstling our graves this produce they emma this growth it delightful this wild our , this name our emma this call our emma
# Epoch time: 71.322s
# Epoch 48 | avg loss: 353.2388
# Sample: jail combined might emma and wild of emma and halls of emma seen name our emma and wild flames emma and those our emma ' older our emma and name
# Epoch time: 72.138s
# Epoch 49 | avg loss: 353.7009
# Sample: ring felt ' name it , ' suppose latter , seen name it only ' name it , ' person retire emma seen ( idle , ardent halls ankles serv
# Epoch time: 71.705s
# Epoch 50 | avg loss: 353.7672
# Sample: thro’ blood to of and call to of and name our of and didn’t to of and whom to of and whom to of watches did to of and whom
# Epoch time: 71.695s

# %%
class SeqDatasetOneHot(Dataset):
    def __init__(self, X, Y, vocab_size):
        self.X = torch.tensor(X, dtype=torch.long)
        self.Y = torch.tensor(Y, dtype=torch.long)
        self.V = vocab_size

    def __len__(self):
        return self.X.size(0)

    def __getitem__(self, idx):
        x_ids = self.X[idx]
        y_ids = self.Y[idx]

        x_oh = torch.zeros(x_ids.size(0), self.V, dtype=torch.float32)
        x_oh.scatter_(1, x_ids.unsqueeze(1), 1.0)
        return x_oh, y_ids


class OneHotRNNLM(nn.Module):
    def __init__(self, vocab_size, hidden=256):
        super().__init__()
        self.rnn = nn.RNN(input_size=vocab_size,
                          hidden_size=hidden, batch_first=True)
        self.fc = nn.Linear(hidden, vocab_size)

    def forward(self, x_oh, h0=None):
        out, hn = self.rnn(x_oh, h0)
        logits = self.fc(out)
        return logits, hn


@torch.no_grad()
def generate(model, stoi, itos, seed_text="<bos>", max_new=40, temperature=1.0):
    model.eval()
    tokens = seed_text.split()
    ids = [stoi.get(t, stoi["<unk>"]) for t in tokens]
    V = len(stoi)

    h = None
    for _ in range(max_new):
        x = torch.tensor(ids[-1:], dtype=torch.long,
                         device=DEVICE)  # last token
        x_oh = torch.zeros(1, 1, V, device=DEVICE)
        x_oh.scatter_(2, x.view(1, 1, 1), 1.0)

        logits, h = model(x_oh, h)
        next_logits = logits[0, -1] / max(temperature, 1e-6)
        probs = torch.softmax(next_logits, dim=0)
        nxt = torch.multinomial(probs, 1).item()
        ids.append(nxt)

    words = [itos[i] for i in ids]
    return " ".join(words)


def rnn_onehot_main():
    text = load_poems()
    tokens = ["<bos>"] + simple_tokenize(text) + ["<eos>"]
    stoi, itos = build_vocab(tokens, min_freq=1)
    ids = tokens_to_ids(tokens, stoi)

    seq_len = 25
    X, Y = make_sequences(ids, seq_len)
    ds = SeqDatasetOneHot(X, Y, vocab_size=len(stoi))
    dl = DataLoader(ds, batch_size=64, shuffle=True, drop_last=True)

    model = OneHotRNNLM(vocab_size=len(stoi), hidden=256).to(DEVICE)
    opt = torch.optim.Adam(model.parameters(), lr=1e-3)
    loss_fn = nn.CrossEntropyLoss()

    print("Training One-Hot RNN on", DEVICE)

    epoch_times = []
    samples = []

    for epoch in range(n_epochs):
        model.train()
        t0 = time.perf_counter()
        total = 0.0
        steps = 0
        for x_oh, y in dl:
            x_oh = x_oh.to(DEVICE)
            y = y.to(DEVICE)

            logits, _ = model(x_oh)
            loss = loss_fn(logits.reshape(-1, logits.size(-1)), y.reshape(-1))

            opt.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            opt.step()

            total += loss.item()
            steps += 1

        print(f"Epoch {epoch+1} | loss: {total/steps:.4f}")

        sample = generate(model, stoi, itos, seed_text="<bos>", max_new=40, temperature=0.9)
        samples.append(sample)

        t1 = time.perf_counter()
        epoch_times.append(float(t1 - t0))

        print("Sample:", sample)
        print(f"Epoch time: {epoch_times[-1]:.3f}s")

    print(f"Total training time (one-hot): {sum(epoch_times):.2f}s")
    return epoch_times, samples[-1]

onehot_rnn_epoch_times, onehot_rnn_last_sample = rnn_onehot_main()
# Out:
# Training One-Hot RNN on mps
# Epoch 1 | loss: 6.2259
# Sample: <bos> crowd and or rides of a ' not who , i think with a , and , cut must not tis speak nor ' the life , i superbly bodies , where i pavement that the be i paths white
# Epoch time: 25.056s
# Epoch 2 | loss: 5.1292
# Sample: <bos> my head and grape earth , did borne lucky the grass , out of the great battery chain stronger the day-break limbs be enamour . ) to god as dying reclines much it other be if with consider have that
# Epoch time: 24.024s
# Epoch 3 | loss: 4.0254
# Sample: <bos> madest when can smile as follow , and i ! it ! astonish love man much and like my man heroes , in heaven to fill on a thousand fool lies me . what goes i look be stop in
# Epoch time: 24.180s
# Epoch 4 | loss: 2.9018
# Sample: <bos> joy . but more than a far ? when can pockets into it—it shall time you be you best stand . i do i am any , precisely by life . and hear say of the beautiful and the glimmer
# Epoch time: 24.562s
# Epoch 5 | loss: 1.8317
# Sample: <bos> text " o my luve ' s like a red , red rose that’s newly sprung in june ; o my luve ' s like the melodie that’s sweetly play ' d in tune . as fair art thou ,
# Epoch time: 25.396s
# Epoch 24 | loss: 0.2168
# Sample: <bos> text " o my luve ' s like a red , the judge with hands tight to the desk , his pallid lips pronouncing a death-sentence , the heave ' e ' yo of stevedores unlading ships by the wharves
# Epoch time: 24.195s
# Epoch 25 | loss: 0.2154
# Sample: <bos> text " o my luve ' s like a red , red rose that’s newly sprung in june ; o my luve ' s like the melodie that’s sweetly play ' d in tune . as fair art thou ,
# Epoch time: 24.096s
# Epoch 26 | loss: 0.2141
# Sample: <bos> text " o my luve ' s like a red , red rose that’s newly sprung in june ; o my luve ' s like the melodie that’s sweetly play ' d in tune . as fair art thou ,
# Epoch time: 23.831s
# Epoch 27 | loss: 0.2127
# Sample: <bos> text " o my luve ' s like a red , red rose that’s newly sprung in june ; o my luve ' s like the melodie that’s sweetly play ' d in tune . as fair art thou ,
# Epoch time: 24.265s
# Epoch 28 | loss: 0.2116
# Sample: <bos> text " o my luve ' s like a red , red rose that’s newly sprung in june ; o my luve ' s like the melodie that’s sweetly play ' d in tune . as fair art thou ,
# Epoch time: 24.119s
# Epoch 29 | loss: 0.2108
# Sample: <bos> text " o my luve ' s like a red , red rose that’s newly sprung in june ; o my luve ' s like the melodie that’s sweetly play ' d in tune . as fair art thou ,
# Epoch time: 23.937s
# Epoch 30 | loss: 0.2096
# Sample: <bos> text " o my luve ' s like a red , red rose that’s newly sprung in june ; o my luve ' s like the melodie that’s sweetly play ' d in tune . as fair art thou ,
# Epoch time: 23.908s
# Epoch 31 | loss: 0.2089
# Sample: <bos> text " o my luve ' s like a red , red rose that’s newly sprung in june ; o my luve ' s like the melodie that’s sweetly play ' d in tune . as fair art thou ,
# Epoch time: 24.153s
# Epoch 32 | loss: 0.2079
# Sample: <bos> text " o my luve ' s like a red , red rose that’s newly sprung in june ; o my luve ' s like the melodie that’s sweetly play ' d in tune . as fair art thou ,
# Epoch time: 24.350s
# Epoch 33 | loss: 0.2072
# Sample: <bos> text " o my luve ' s like a red , red rose that’s newly sprung in june ; o my luve ' s like the melodie that’s sweetly play ' d in tune . as fair art thou ,
# Epoch time: 24.731s
# Epoch 34 | loss: 0.2068
# Sample: <bos> text " o my luve ' s like a red , red rose that’s newly sprung in june ; o my luve ' s like the melodie that’s sweetly play ' d in tune . as fair art thou ,
# Epoch time: 23.902s
# Epoch 35 | loss: 0.2061
# Sample: <bos> text " o my luve ' s like a red , red rose that’s newly sprung in june ; o my luve ' s like the melodie that’s sweetly play ' d in tune . as fair art thou ,
# Epoch time: 24.013s
# Epoch 36 | loss: 0.2054
# Sample: <bos> text " o my luve ' s like a red , red rose that’s newly sprung in june ; o my luve ' s like the melodie that’s sweetly play ' d in tune . as fair art thou ,
# Epoch time: 25.267s
# Epoch 37 | loss: 0.2049
# Sample: <bos> text " o my luve ' s like a red , red rose that’s newly sprung in june ; o my luve ' s like the melodie that’s sweetly play ' d in tune . as fair art thou ,
# Epoch time: 23.979s
# Epoch 38 | loss: 0.2044
# Sample: <bos> text " o my luve ' s like a red , red rose that’s newly sprung in june ; o my luve ' s like a melodie that’s sweetly play ' d in tune . as fair art thou ,
# Epoch time: 23.967s
# Epoch 39 | loss: 0.2040
# Sample: <bos> text " o my luve ' s like a red , red rose that’s newly sprung in june ; o my luve ' s like the melodie that’s sweetly play ' d in tune . as fair art thou ,
# Epoch time: 23.874s
# Epoch 40 | loss: 0.2032
# Sample: <bos> text " o my luve ' s like a red , red rose that’s newly sprung in june ; o my luve ' s like the melodie that’s sweetly play ' d in tune . as fair art thou ,
# Epoch time: 24.025s
# Epoch 41 | loss: 0.2029
# Sample: <bos> text " o my luve ' s like a red , red rose that’s newly sprung in june ; o my luve ' s like the melodie that’s sweetly play ' d in tune . as fair art thou ,
# Epoch time: 24.099s
# Epoch 42 | loss: 0.2026
# Sample: <bos> text " o my luve ' s like a red , red rose that’s newly sprung in june ; o my luve ' s like the melodie that’s sweetly play ' d in tune . as fair art thou ,
# Epoch time: 24.031s
# Epoch 43 | loss: 0.2020
# Sample: <bos> text " o my luve ' s like a red , red rose that’s newly sprung in june ; o my luve ' s like the melodie that’s sweetly play ' d in tune . as fair art thou ,
# Epoch time: 24.015s
# Epoch 44 | loss: 0.2017
# Sample: <bos> text " o my luve ' s like a red , red rose that’s newly sprung in june ; o my luve ' s like the melodie that’s sweetly play ' d in tune . as fair art thou ,
# Epoch time: 23.835s
# Epoch 45 | loss: 0.2015
# Sample: <bos> text " o my luve ' s like a red , red rose that’s newly sprung in june ; o my luve ' s like the melodie that’s sweetly play ' d in tune . as fair art thou ,
# Epoch time: 24.274s
# Epoch 46 | loss: 0.2010
# Sample: <bos> text " o my luve ' s like a red , red rose that’s newly sprung in june ; o my luve ' s like the melodie that’s sweetly play ' d in tune . as fair art thou ,
# Epoch time: 24.364s
# Epoch 47 | loss: 0.2007
# Sample: <bos> text " o my luve ' s like a red , red rose that’s newly sprung in june ; o my luve ' s like the melodie that’s sweetly play ' d in tune . as fair art thou ,
# Epoch time: 24.023s
# Epoch 48 | loss: 0.2003
# Sample: <bos> text " o my luve ' s like a red , red rose that’s newly sprung in june ; o my luve ' s like the melodie that’s sweetly play ' d in tune . as fair art thou ,
# Epoch time: 24.073s
# Epoch 49 | loss: 0.2000
# Sample: <bos> text " o my luve ' s like a red , red rose that’s newly sprung in june ; o my luve ' s like the melodie that’s sweetly play ' d in tune . as fair art thou ,
# Epoch time: 24.144s
# Epoch 50 | loss: 0.1998
# Sample: <bos> text " o my luve ' s like a red , red rose that’s newly sprung in june ; o my luve ' s like the melodie that’s sweetly play ' d in tune . as fair art thou ,
# Epoch time: 24.049s
# Total training time (one-hot): 1213.80s

# %%
class SeqDatasetIdx(Dataset):
    def __init__(self, X, Y):
        self.X = torch.tensor(X, dtype=torch.long)
        self.Y = torch.tensor(Y, dtype=torch.long)

    def __len__(self):
        return self.X.size(0)

    def __getitem__(self, idx):
        return self.X[idx], self.Y[idx]


class EmbRNNLM(nn.Module):
    def __init__(self, vocab_size, emb=128, hidden=256):
        super().__init__()
        self.emb = nn.Embedding(vocab_size, emb)
        self.rnn = nn.RNN(input_size=emb, hidden_size=hidden, batch_first=True)
        self.fc = nn.Linear(hidden, vocab_size)

    def forward(self, x_ids, h0=None):
        x = self.emb(x_ids)
        out, hn = self.rnn(x, h0)
        logits = self.fc(out)
        return logits, hn


@torch.no_grad()
def generate(model, stoi, itos, seed_text="<bos>", max_new=40, temperature=1.0):
    model.eval()
    tokens = seed_text.split()
    ids = [stoi.get(t, stoi["<unk>"]) for t in tokens]

    h = None
    for _ in range(max_new):
        x = torch.tensor([[ids[-1]]], dtype=torch.long, device=DEVICE)
        logits, h = model(x, h)
        next_logits = logits[0, -1] / max(temperature, 1e-6)
        probs = torch.softmax(next_logits, dim=0)
        nxt = torch.multinomial(probs, 1).item()
        ids.append(nxt)

    return " ".join(itos[i] for i in ids)


def rnn_embedding_main():
    text = load_poems()
    tokens = ["<bos>"] + simple_tokenize(text) + ["<eos>"]
    stoi, itos = build_vocab(tokens, min_freq=1)
    ids = tokens_to_ids(tokens, stoi)

    seq_len = 25
    X, Y = make_sequences(ids, seq_len)
    ds = SeqDatasetIdx(X, Y)
    dl = DataLoader(ds, batch_size=64, shuffle=True, drop_last=True)

    model = EmbRNNLM(vocab_size=len(stoi), emb=128, hidden=256).to(DEVICE)
    opt = torch.optim.Adam(model.parameters(), lr=1e-3)
    loss_fn = nn.CrossEntropyLoss()

    print("Training Embedding RNN on", DEVICE)

    epoch_times = []
    samples = []

    for epoch in range(n_epochs):
        model.train()
        t0 = time.perf_counter()
        total = 0.0
        steps = 0
        for x_ids, y in dl:
            x_ids = x_ids.to(DEVICE)
            y = y.to(DEVICE)

            logits, _ = model(x_ids)
            loss = loss_fn(logits.reshape(-1, logits.size(-1)), y.reshape(-1))

            opt.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            opt.step()

            total += loss.item()
            steps += 1

        print(f"Epoch {epoch+1} | loss: {total/steps:.4f}")

        sample = generate(model, stoi, itos, seed_text="<bos>", max_new=40, temperature=0.9)
        samples.append(sample)

        t1 = time.perf_counter()
        epoch_times.append(float(t1 - t0))

        print("Sample:", sample)
        print(f"Epoch time: {epoch_times[-1]:.3f}s")

    print(f"Total training time (embedding): {sum(epoch_times):.2f}s")
    return epoch_times, samples[-1]

embedding_rnn_epoch_times, embedding_rnn_last_sample = rnn_embedding_main()
# Out:
# Training Embedding RNN on mps
# Epoch 1 | loss: 5.0979
# Sample: <bos> born to their of ascending , and women maiden flowers , and the wilds of may young the steeps of it , and make you also—i meanwhile thro in your flows , he lies the winged slave of the old
# Epoch time: 15.155s
# Epoch 2 | loss: 2.6033
# Sample: <bos> you close the violoncello when gay and memory nations see , my heart and i leave us with animals and in it on the early redstart ; and with my heart and i . ii . what does only time
# Epoch time: 14.541s
# Epoch 3 | loss: 1.2063
# Sample: <bos> you see myself , ) my signs are a rain-proof coat , good shoes , and a voice of thee , nor love , while i listened , seemed like the wild growth or through the priest trees , they
# Epoch time: 13.613s
# Epoch 4 | loss: 0.6458
# Sample: <bos> your love , till the thoughtful merge of myself , and the dark and the fish-eggs are in the world . the passing of sticks cooking my meals , i lean the cove and narrow eyes , i feel the
# Epoch time: 13.571s
# Epoch 5 | loss: 0.4422
# Sample: <bos> text a song , hath awaken ' d a thousand acres much ? have you dream ' d my spirit flew , saw other regions , cities new , as the world rush ' d by on either side .
# Epoch time: 13.659s
# Epoch 6 | loss: 0.3584
# Sample: <bos> text a shake hands then ? this air is the organ loft , the carpenter dresses his plank , the tongue of his foreplane whistles its wild ascending lisp , the married and unmarried children ride home to their thanksgiving
# Epoch time: 13.622s
# Epoch 7 | loss: 0.3154
# Sample: <bos> text their you are have been boys and i like a cup with soft balsamic busses , noiselessly passing handfuls out of their hearts and giving them to be mine . old loved like stars , it flings my likeness
# Epoch time: 13.584s
# Epoch 8 | loss: 0.2893
# Sample: <bos> text " the spotted hawk swoops by and accuses me , he complains of my gab and my loitering . i ascend from the night , i perceive that the ghastly glimmer is noonday sunbeams reflected , and debouch to
# Epoch time: 13.526s
# Epoch 9 | loss: 0.2717
# Sample: <bos> text d with the stuff that is fine , one of the nation of many nations , the smallest the same and the largest the same , a southerner soon as a northerner , a planter nonchalant and hospitable down
# Epoch time: 13.628s
# Epoch 10 | loss: 0.2595
# Sample: <bos> text " o sorrow , cruel fellowship , o priestess in the vaults of death , o sweet and bitter in a breath , what whispers from thy lying lip ? ‘the stars , ’ she whispers , ‘blindly run
# Sample: <bos> text " o my luve ' s like a red , red rose that’s newly sprung in june ; o my luve ' s like the melodie that’s sweetly play ' d in tune . as fair art thou ,
# Epoch time: 13.688s
# Epoch 38 | loss: 0.2077
# Sample: <bos> text " o my luve ' s like a red , red rose that’s newly sprung in june ; o my luve ' s like the melodie that’s sweetly play ' d in tune . as fair art thou ,
# Epoch time: 13.730s
# Epoch 39 | loss: 0.2077
# Sample: <bos> text " o my luve ' s like a red , red rose that’s newly sprung in june ; o my luve ' s like the melodie that’s sweetly play ' d in tune . as fair art thou ,
# Epoch time: 13.494s
# Epoch 40 | loss: 0.2071
# Sample: <bos> text " o my luve ' s like a red , red rose that’s newly sprung in june ; o my luve ' s like the melodie that’s sweetly play ' d in tune . as fair art thou ,
# Epoch time: 13.597s
# Epoch 41 | loss: 0.2071
# Sample: <bos> text " o my luve ' s like a red , red rose that’s newly sprung in june ; o my luve ' s like the melodie that’s sweetly play ' d in tune . as fair art thou ,
# Epoch time: 13.635s
# Epoch 42 | loss: 0.2068
# Sample: <bos> text " o my luve ' s like a red , red rose that’s newly sprung in june ; o my luve ' s like the melodie that’s sweetly play ' d in tune . as fair art thou ,
# Epoch time: 13.761s
# Epoch 43 | loss: 0.2065
# Sample: <bos> text " o my luve ' s like a red , red rose that’s newly sprung in june ; o my luve ' s like the melodie that’s sweetly play ' d in tune . as fair art thou ,
# Epoch time: 13.737s
# Epoch 44 | loss: 0.2063
# Sample: <bos> text " o my luve ' s like a red , red rose that’s newly sprung in june ; o my luve ' s like the melodie that’s sweetly play ' d in tune . as fair art thou ,
# Epoch time: 13.569s
# Epoch 45 | loss: 0.2062
# Sample: <bos> text " o my luve ' s like a red , red rose that’s newly sprung in june ; o my luve ' s like the melodie that’s sweetly play ' d in tune . as fair art thou ,
# Epoch time: 13.567s
# Epoch 46 | loss: 0.2058
# Sample: <bos> text " o my luve ' s like a red , red rose that’s newly sprung in june ; o my luve ' s like the melodie that’s sweetly play ' d in tune . as fair art thou ,
# Epoch time: 13.601s
# Epoch 47 | loss: 0.2058
# Sample: <bos> text " o my luve ' s like a red , red rose that’s newly sprung in june ; o my luve ' s like the melodie that’s sweetly play ' d in tune . as fair art thou ,
# Epoch time: 13.585s
# Epoch 48 | loss: 0.2057
# Sample: <bos> text " o my luve ' s like a red , red rose that’s newly sprung in june ; o my luve ' s like the melodie that’s sweetly play ' d in tune . as fair art thou ,
# Epoch time: 13.653s
# Epoch 49 | loss: 0.2060
# Sample: <bos> text " o my luve ' s like a red , red rose that’s newly sprung in june ; o my luve ' s like the melodie that’s sweetly play ' d in tune . as fair art thou ,
# Epoch time: 13.781s
# Epoch 50 | loss: 0.2055
# Sample: <bos> text " o my luve ' s like the melodie that’s sweetly play ' d in tune . as fair art thou , my bonnie lass , so deep in luve am i : and i will luve thee still
# Epoch time: 13.717s
# Total training time (embedding): 684.67s

# %%
total_scratch_rnn_time = sum(scratch_rnn_epoch_times)
total_onehot_rnn_time = sum(onehot_rnn_epoch_times)
total_embedding_rnn_time = sum(embedding_rnn_epoch_times)

print(f"Total training time (Scratch RNN): {total_scratch_rnn_time:.2f}s")
print(f"Total training time (One-Hot RNN): {total_onehot_rnn_time:.2f}s")
print(f"Total training time (Embedding RNN): {total_embedding_rnn_time:.2f}s")
# Out:
# Total training time (Scratch RNN): 3660.39s
# Total training time (One-Hot RNN): 1213.80s
# Total training time (Embedding RNN): 684.67s

# %%
scratch_rnn_metrics = text_quality_metrics(scratch_rnn_last_sample)
onehot_rnn_metrics = text_quality_metrics(onehot_rnn_last_sample)
embedding_rnn_metrics = text_quality_metrics(embedding_rnn_last_sample)

print("Scratch RNN Metrics:")
print(scratch_rnn_metrics)
print("\nOne-Hot RNN Metrics:")
print(onehot_rnn_metrics)
print("\nEmbedding RNN Metrics:")
print(embedding_rnn_metrics)
# Out:
# Scratch RNN Metrics:
# {'token_count': 30, 'unique_tokens': 12, 'unique_ratio': 0.4, 'repeat_2gram_ratio': 0.4482758620689655, 'repeat_3gram_ratio': 0.2857142857142857, 'top_tokens': [('of', 7), ('to', 6), ('and', 6), ('whom', 3), ('thro’', 1), ('blood', 1), ('call', 1), ('name', 1), ('our', 1), ('didn’t', 1)]}
#
# One-Hot RNN Metrics:
# {'token_count': 41, 'unique_tokens': 30, 'unique_ratio': 0.7317073170731707, 'repeat_2gram_ratio': 0.125, 'repeat_3gram_ratio': 0.10256410256410256, 'top_tokens': [("'", 3), ('o', 2), ('my', 2), ('luve', 2), ('s', 2), ('like', 2), ('red', 2), (',', 2), ('that’s', 2), ('in', 2)]}
#
# Embedding RNN Metrics:
# {'token_count': 41, 'unique_tokens': 34, 'unique_ratio': 0.8292682926829268, 'repeat_2gram_ratio': 0.0, 'repeat_3gram_ratio': 0.0, 'top_tokens': [('luve', 3), ('my', 2), ("'", 2), ('in', 2), (',', 2), ('i', 2), ('<bos>', 1), ('text', 1), ('"', 1), ('o', 1)]}
